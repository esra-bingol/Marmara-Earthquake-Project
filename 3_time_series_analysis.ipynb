# %% [markdown]
# # 📆 Bölüm 3: Zaman Serisi Analizi
#
# Bu bölümde Marmara ve İstanbul bölgelerindeki depremlerin yıllık ve aylık zaman içindeki değişimi incelenmektedir. Amaç, bölgedeki sismik aktivitenin yıllara göre nasıl bir eğilim gösterdiğini ortaya koymaktır.
#
# ## Hedefler:
# - Yıllara göre toplam deprem sayısı
# - Ortalama büyüklük (ML) değişimi
# - Opsiyonel: Aylık sezonsal trend

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("marmara_faults_earthquakes_2000_2025.csv")
df['Date'] = pd.to_datetime(df['Date'])

# Marmara filtreleme
df_marmara = df[(df['Latitude'] > 39) & (df['Latitude'] < 42) & 
                (df['Longitude'] > 26) & (df['Longitude'] < 31)].copy()

# %%
# Yıl sütunu oluşumu
df_marmara['Year'] = df_marmara['Date'].dt.year

# Yıllık toplam deprem sayısı
yearly_counts = df_marmara.groupby('Year').size()

# Görselleştirme adımı
plt.figure(figsize=(10, 5))
sns.lineplot(x=yearly_counts.index, y=yearly_counts.values, marker='o')
plt.title('Marmara Bölgesi - Yıllık Deprem Sayısı (2000–2025)')
plt.xlabel('Yıl')
plt.ylabel('Deprem Sayısı')
plt.grid(True)
plt.show()
